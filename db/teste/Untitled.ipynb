# %%
import pandas as pd

# %%
df = pd.read_csv("../test.csv")
df
# Out:
#      code          name                                         txt_ementa  \
# 0   21785  PRC 130/1997  Acrescenta parágrafo único ao art. 155 do Regi...
# 1   20683  PL 4117/1998  Dispõe sobre o acesso a ambientes de uso colet...
# 2   20857  PL 4395/1998  Estabelece as Diretrizes Nacionais de Defesa C...
# 3   16357  PL 1165/1999  Altera dispositivo da Lei nº 8.987, de 13 de f...
# 4   20464  PL 3927/2000  Altera a composição dos Tribunais Regionais do...
# ..    ...           ...                                                ...
# 95  27974  PL 4551/2001  Acrescenta dispositivo à Lei nº 10.169, de 29 ...
# 96  27984  PL 4561/2001  Acresce dispositivos na Lei nº 9.393, de 19 de...
# 97  27986  PL 4563/2001  Altera a Lei nº 6.938, de 31 de agosto de 1981...
# 98  27988  PL 4565/2001  Dispõe sobre a autorização à doação ou venda a...
# 99  27956  PL 4569/2001  Dá nova redação ao art. 2º da Lei nº 9.870, de...
#
#                                                  text  \
# ...
